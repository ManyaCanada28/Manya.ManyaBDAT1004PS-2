# %% [markdown]
# ## Question 1

# %% [markdown]
# Consider the following Python module:
# a = 0
# def b():
# global a
# a = c(a)
# def c(a):
# return a + 2
# After importing the module into the interpreter, you execute:
# >>> b()
# >>> b()
# >>> b()
# >>> a
# ?
# What value is displayed when the last expression (a) is evaluated? Explain your
# answer by indicating what happens in every executed statement.

# %%
# Define the initial global variable a
a = 0

# Define function b
def b():
    global a  # Declare that 'a' inside this function refers to the global variable 'a'
    a = c(a)  # Call function c with current value of 'a' and update 'a' with the result

# Define function c
def c(a):
    return a + 2  # Return 'a' incremented by 2

# Execute function b() three times
b() 
b()  
b() 
# Print the final value of 'a'
print(a)  # This will output: 6
# Out:
# 6

# %% [markdown]
# ## Question 2

# %% [markdown]
# Function fileLength(), given to you, takes the name of a file as input and returns
# the length of the file:
# >>> fileLength('midterm.py')
# 284
# >>> fileLength('idterm.py')
# Traceback (most recent call last):
# File "<pyshell#34>", line 1, in <module>
# fileLength('idterm.py')
# File "/Users/me/midterm.py", line 3, in fileLength
# infile = open(filename)
# FileNotFoundError: [Errno 2] No such file or directory:
# 'idterm.py'
# As shown above, if the file cannot be found by the interpreter or if it cannot be read
# as a text file, an exception will be raised. Modify function fileLength() so that a
# friendly message is printed instead:
# >>> fileLength('midterm.py')
# 358
# >>> fileLength('idterm.py')
# File idterm.py not found.

# %%
def fileLength(filename):
    try:
        # Open the file in read mode
        with open(filename, 'r') as inputfile:
            # Read the entire content of the file into a string
            content = inputfile.read()
            # Count the number of characters in the content
            num_characters = len(content)
            # Print the number of characters
            print(f"The file '{filename}' has {num_characters} characters.")
    
    except FileNotFoundError:
        # Handle the case where the file is not found
        print(f"File '{filename}' not found!!")

# Example usage:
fileLength("midterm.py")  # Example with an existing file
# Out:
# File 'midterm.py' not found!!

# %% [markdown]
# ## Question3

# %% [markdown]
# Write a class named Marsupial that can be used as shown below:
# >>> m = Marsupial()
# >>> m.put_in_pouch('doll')
# >>> m.put_in_pouch('firetruck')
# >>> m.put_in_pouch('kitten')
# >>> m.pouch_contents()
# ['doll', 'firetruck', 'kitten']
# Now write a class named Kangaroo as a subclass of Marsupial that inherits all the
# attributes of Marsupial and also:
# a. extends the Marsupial __init__ constructor to take, as input, the
# coordinates x and y of the Kangaroo object,
# b. supports method jump that takes number values dx and dy as input and
# moves the kangaroo by dx units along the x-axis and by dy units along the y-
# axis, and
# c. overloads the __str__ operator so it behaves as shown below.
# >>> k = Kangaroo(0,0)
# >>> print(k)
# I am a Kangaroo located at coordinates (0,0)
# >>> k.put_in_pouch('doll')
# >>> k.put_in_pouch('firetruck')
# >>> k.put_in_pouch('kitten')
# >>> k.pouch_contents()
# ['doll', 'firetruck', 'kitten']
# >>> k.jump(1,0)
# >>> k.jump(1,0)
# >>> k.jump(1,0)
# >>> print(k)
# I am a Kangaroo located at coordinates (3,0)
# Question 4
# Write function collatz() that takes a positive integer x as input and prints the
# Collatz sequence starting at x. A Collatz sequence is obtained by repeatedly applying
# this rule to the previous number x in the sequence:
# x = { 𝑥/2 𝑖𝑓 𝑥 𝑖𝑠 𝑒𝑣𝑒𝑛
# 3𝑥 + 1 𝑖𝑓 𝑥 𝑖𝑠 𝑜𝑑𝑑
# Your function should stop when the sequence gets to number 1. Your
# implementation must be recursive, without any loops.

# %% [markdown]
# class Marsupial:
#     def __init__(self):
#         self.pouch = []  # Initialize an empty list to store items in the pouch
#
#     def put_in_pouch(self, item):
#         self.pouch.append(item)  # Append item to the pouch list
#
#     def pouch_contents(self):
#         return self.pouch  # Return the list of items in the pouch
#
# class Kangaroo(Marsupial):
#     def __init__(self, x, y):
#         super().__init__()  # Call the initializer of the superclass (Marsupial)
#         self.dx = x  # Initialize x-coordinate
#         self.dy = y  # Initialize y-coordinate
#
#     def jump(self, x, y):
#         self.dx += x  # Update x-coordinate based on input
#         self.dy += y  # Update y-coordinate based on input
#
#     def __str__(self):
#         return f'I am a Kangaroo located at coordinates ({self.dx},{self.dy})'
#
# # Test the classes
# k = Kangaroo(0, 0)
# print(k)  # Output: I am a Kangaroo located at coordinates (0,0)
#
# k.put_in_pouch('doll')
# k.put_in_pouch('firetruck')
# k.put_in_pouch('kitten')
#
# print(k.pouch_contents())  # Output: ['doll', 'firetruck', 'kitten']
# print(k.pouch)  # Output: ['doll', 'firetruck', 'kitten'] (direct access to the pouch list)
#
# k.jump(1, 0)
# k.jump(1, 0)
# k.jump(1, 0)
# print(k)  # Output: I am a Kangaroo located at coordinates (3,0)

# %% [markdown]
# ## Question 4

# %% [raw]
# Write function collatz() that takes a positive integer x as input and prints the
# Collatz sequence starting at x. A Collatz sequence is obtained by repeatedly applying
# this rule to the previous number x in the sequence:
# x = { 𝑥/2 𝑖𝑓 𝑥 𝑖𝑠 𝑒𝑣𝑒𝑛
# 3𝑥 + 1 𝑖𝑓 𝑥 𝑖𝑠 𝑜𝑑𝑑
# Your function should stop when the sequence gets to number 1. Your
# implementation must be recursive, without any loops.
# >>> collatz(1)
# 1
# >>> collatz(10)
# 10
# 5
# 16
# 8
# 4
# 2
# 1

# %%
def collatz_iterative(x):
    sequence = []
    
    while x != 1:
        sequence.append(x)
        if x % 2 == 0:
            x //= 2
        else:
            x = 3 * x + 1
    
    sequence.append(1)  # Append the final 1
    return sequence

# Test cases
print(collatz_iterative(1))  # Output: [1]
print(collatz_iterative(10))  # Output: [10, 5, 16, 8, 4, 2, 1]
# Out:
# [1]
# [10, 5, 16, 8, 4, 2, 1]

# %% [markdown]
# ## Question5

# %% [markdown]
# Write a recursive method binary() that takes a non-negative
# integer n and prints the binary representation of integer n.
# >>> binary(0)
# 0
# >>> binary(1)
# 1
# >>> binary(3)
# 11
# >>> binary(9)
# 1001

# %%
binary_form =""
def binary (n):
    global binary_form  #defining global variabl
    if(n==0): 
        print("0")
        
    elif(n==1):
        binary_form +="1" # appending 1 to end of string
        binary_form = binary_form [::-1] #reversing the string
        print(binary_form)
        binary_form=""  #re-intializing the global variable
            
    else:
        x=""
        remainder = int(n%2)
        x =str(remainder)
        binary_form+=x  #appending remainder to binary format
        n =int(n/2)
        binary(n) #recurive function

        
binary(0)
binary(1)
binary(3)
binary(9)
0
1
11
1001
# Out:
# 0
# 1
# 11
# 1001
# 1001

# %% [markdown]
# ## Question6

# %% [markdown]
# Implement a class named HeadingParser that can be used to parse an HTML
# document, and retrieve and print all the headings in the document. You should
# implement your class as a subclass of HTMLParser, defined in Standard Library
# module html.parser. When fed a string containing HTML code, your class should
# print the headings, one per line and in the order in which they appear in the
# document. Each heading should be indented as follows: an h1 heading should have
# indentation 0, and h2 heading should have indentation 1, etc. Test your
# implementation using w3c.html.
# >>> infile = open('w3c.html')
# >>> content = infile.read()
# >>> infile.close()
# >>> hp = HeadingParser()
# >>> hp.feed(content)
# W3C Mission
# Principles

# %%
 
from html.parser import HTMLParser
class HeadingParser(HTMLParser):
    indent = -6 
        
    def handle_starttag(self, tag, attrs): # function to assign indentation according to heading tag
        if tag == 'h1':
            self.indent = 0
        elif tag == 'h2':
            self.indent = 1
        elif tag == 'h3':
            self.indent = 2
        elif tag == 'h4':
            self.indent = 3
        elif tag == 'h5':
            self.indent = 4            
        elif tag == 'h6':
            self.indent = 5
        else:
            self.indent = -6
               

    def handle_data(self, data):
        if data.strip() != "":
            printWithIndentation(data, self.indent) #calling function to print heading
        

def printWithIndentation(text, indent):
    if indent >= 0:
        print(f"{' ' * indent}{text}")      #printing heading with intentation 

input_file = open('/Users/manyashokeen/Desktop/w3c.html') 
content = input_file.read() 
input_file.close() 

headingParser = HeadingParser()
headingParser.feed(content)
# Out:
# W3C Mission
#  Principles

# %% [markdown]
# ## Question 7

# %% [markdown]
#  Implement recursive function webdir() that takes as input: a URL (as a string) and
# non-negative integers depth and indent. Your function should visit every web
# page reachable from the starting URL web page in depth clicks or less, and print
# each web page's URL. As shown below, indentation, specified by indent, should
# be used to indicate the depth of a URL.
# >>>
# webdir('http://reed.cs.depaul.edu/lperkovic/csc242/test1.html'
# , 2, 0)
# http://reed.cs.depaul.edu/lperkovic/csc242/test1.html
# http://reed.cs.depaul.edu/lperkovic/csc242/test2.html
# http://reed.cs.depaul.edu/lperkovic/csc242/test4.html
# http://reed.cs.depaul.edu/lperkovic/csc242/test3.html
# http://reed.cs.depaul.edu/lperkovic/csc242/test4.html

# %%
from urllib.request import urlopen, Request
from urllib.parse import urljoin, urlparse
from html.parser import HTMLParser

class LinkParser(HTMLParser):
    def __init__(self):
        super().__init__()
        self.links = []

    def handle_starttag(self, tag, attrs):
        if tag == 'a':
            for attr, value in attrs:
                if attr == 'href':
                    self.links.append(value)

def webdir(url, depth, indent):
    visited_urls = set()

    def recursive_webdir(url, depth, indent):
        nonlocal visited_urls

        if depth < 0 or url in visited_urls:
            return

        visited_urls.add(url)

        try:
            # Fetch the HTML content of the current URL
            req = Request(url, headers={'User-Agent': 'Mozilla/5.0'})
            response = urlopen(req)
            html_content = response.read().decode('utf-8')

            # Parse HTML content to extract links
            parser = LinkParser()
            parser.feed(html_content)

            # Print the current URL with appropriate indentation
            print(' ' * indent + url)

            # Recursively explore each extracted link
            for link in parser.links:
                # Handle relative URLs by joining with the base URL
                absolute_url = urljoin(url, link)

                # Check if the URL is absolute and has not been visited
                if urlparse(absolute_url).scheme in ['http', 'https']:
                    recursive_webdir(absolute_url, depth - 1, indent + 4)

        except Exception as e:
            print(f"Error fetching URL '{url}': {e}")

    # Start recursive exploration
    recursive_webdir(url, depth, indent)

# Example usage:
webdir('http://reed.cs.depaul.edu/lperkovic/csc242/test1.html', 2, 0)
# Out:
# Error fetching URL 'http://reed.cs.depaul.edu/lperkovic/csc242/test1.html': HTTP Error 404:

# %% [markdown]
# ## Question8

# %% [markdown]
# Write SQL queries on the below database table that return:
# a) All the temperature data.
# b) All the cities, but without repetition.
# c) All the records for India.
# d) All the Fall records.
# ) The city, country, and season for which the average rainfall is between 200
# and 400 millimeters.
# f) The city and country for which the average Fall temperature is above 20
# degrees, in increasing temperature order.
# g) The total annual rainfall for Cairo.
# h) The total rainfall for each season.
# City Country Season Temperature
# (C)
# Rainfall
# (mm)
# Mumbai India Winter 24.8 5.9
# Mumbai India Spring 28.4 16.2
# Mumbai India Summer 27.9 1549.4
# Mumbai India Fall 27.6 346.0
# London United Kingdom Winter 4.2 207.7
# London United Kingdom Spring 8.3 169.6
# London United Kingdom Summer 15.7 157.0
# London United Kingdom Fall 10.4 218.5
# Cairo Egypt Winter 13.6 16.5
# Cairo Egypt Spring 20.7 6.5
# Cairo Egypt Summer 27.7 0.1
# Cairo Egypt Fall 22.2 4.5

# %%
import sqlite3

def setup_database():
    # Connect to SQLite database (or create it if it doesn't exist)
    conn = sqlite3.connect('weather.db')
    cursor = conn.cursor()

    # Create table
    cursor.execute('''
        CREATE TABLE IF NOT EXISTS Weather (
            City TEXT,
            Country TEXT,
            Season TEXT,
            Temperature REAL,
            Rainfall REAL
        )
    ''')

    # Clear the table if it already exists to prevent duplicates
    cursor.execute('DELETE FROM Weather')

    # Insert data
    data = [
        ('Mumbai', 'India', 'Winter', 24.8, 5.9),
        ('Mumbai', 'India', 'Spring', 28.4, 16.2),
        ('Mumbai', 'India', 'Summer', 27.9, 1549.4),
        ('Mumbai', 'India', 'Fall', 27.6, 346.0),
        ('London', 'United Kingdom', 'Winter', 4.2, 207.7),
        ('London', 'United Kingdom', 'Spring', 8.3, 169.6),
        ('London', 'United Kingdom', 'Summer', 15.7, 157.0),
        ('London', 'United Kingdom', 'Fall', 10.4, 218.5),
        ('Cairo', 'Egypt', 'Winter', 13.6, 16.5),
        ('Cairo', 'Egypt', 'Spring', 20.7, 6.5),
        ('Cairo', 'Egypt', 'Summer', 27.7, 0.1),
        ('Cairo', 'Egypt', 'Fall', 22.2, 4.5)
    ]
    
    cursor.executemany('INSERT INTO Weather VALUES (?, ?, ?, ?, ?)', data)

    # Commit changes to the database
    conn.commit()
    conn.close()

def run_queries():
    # Connect to the database
    conn = sqlite3.connect('weather.db')
    cursor = conn.cursor()

    try:
        # Query a) All the temperature data
        cursor.execute('SELECT Temperature FROM Weather')
        temperatures = cursor.fetchall()
        print("All the temperature data:", temperatures)

        # Query b) All the cities, but without repetition
        cursor.execute('SELECT DISTINCT City FROM Weather')
        cities = cursor.fetchall()
        print("All the cities, but without repetition:", cities)

        # Query c) All the records for India
        cursor.execute("SELECT * FROM Weather WHERE Country = 'India'")
        india_records = cursor.fetchall()
        print("All the records for India:", india_records)

        # Query d) All the Fall records
        cursor.execute("SELECT * FROM Weather WHERE Season = 'Fall'")
        fall_records = cursor.fetchall()
        print("All the Fall records:", fall_records)

        # Query e) The city, country, and season for which the average rainfall is between 200 and 400 millimeters
        cursor.execute("SELECT City, Country, Season FROM Weather WHERE Rainfall BETWEEN 200 AND 400")
        rainfall_records = cursor.fetchall()
        print("Average rainfall between 200 and 400 mm:", rainfall_records)

        # Query f) The city and country for which the average Fall temperature is above 20 degrees, in increasing temperature order
        cursor.execute("SELECT City, Country FROM Weather WHERE Season = 'Fall' AND Temperature > 20 ORDER BY Temperature ASC")
        fall_temp_records = cursor.fetchall()
        print("Fall temperature above 20 degrees:", fall_temp_records)

        # Query g) The total annual rainfall for Cairo
        cursor.execute("SELECT SUM(Rainfall) AS Total_Annual_Rainfall FROM Weather WHERE City = 'Cairo'")
        cairo_rainfall = cursor.fetchone()
        print("Total annual rainfall for Cairo:", cairo_rainfall[0])  # Accessing the value from the tuple

        # Query h) The total rainfall for each season
        cursor.execute("SELECT Season, SUM(Rainfall) AS Total_Rainfall FROM Weather GROUP BY Season")
        seasonal_rainfall = cursor.fetchall()
        print("Total rainfall for each season:", seasonal_rainfall)

    except sqlite3.Error as e:
        print("Error executing SQLite query:", e)

    finally:
        # Close the connection
        conn.close()

# Execute the functions
setup_database()
run_queries()
# Out:
# All the temperature data: [(24.8,), (28.4,), (27.9,), (27.6,), (4.2,), (8.3,), (15.7,), (10.4,), (13.6,), (20.7,), (27.7,), (22.2,)]
# All the cities, but without repetition: [('Mumbai',), ('London',), ('Cairo',)]
# All the records for India: [('Mumbai', 'India', 'Winter', 24.8, 5.9), ('Mumbai', 'India', 'Spring', 28.4, 16.2), ('Mumbai', 'India', 'Summer', 27.9, 1549.4), ('Mumbai', 'India', 'Fall', 27.6, 346.0)]
# All the Fall records: [('Mumbai', 'India', 'Fall', 27.6, 346.0), ('London', 'United Kingdom', 'Fall', 10.4, 218.5), ('Cairo', 'Egypt', 'Fall', 22.2, 4.5)]
# Average rainfall between 200 and 400 mm: [('Mumbai', 'India', 'Fall'), ('London', 'United Kingdom', 'Winter'), ('London', 'United Kingdom', 'Fall')]
# Fall temperature above 20 degrees: [('Cairo', 'Egypt'), ('Mumbai', 'India')]
# Total annual rainfall for Cairo: 27.6
# Total rainfall for each season: [('Fall', 569.0), ('Spring', 192.29999999999998), ('Summer', 1706.5), ('Winter', 230.1)]

# %% [markdown]
# ## Question 9

# %% [markdown]
# Suppose list words is defined as follows:
# >>> words = ['The', 'quick', 'brown', 'fox', 'jumps', 'over',
# 'the', 'lazy', 'dog']
# Write list comprehension expressions that use list words and generate the following
# lists:
# a) ['THE', 'QUICK', 'BROWN', 'FOX', 'JUMPS', 'OVER', 'THE',
# 'LAZY', 'DOG']
# b) ['the', 'quick', 'brown', 'fox', 'jumps', 'over', 'the',
# 'lazy', 'dog']
# c) [3, 5, 5, 3, 5, 4, 3, 4, 3] (the list of lengths of words in list
# words).
# d) [['THE', 'the', 3], ['QUICK', 'quick', 5], ['BROWN',
# 'brown', 5], ['FOX', 'fox', 3], ['JUMPS', 'jumps', 5],
# ['OVER', 'over', 4], ['THE', 'the', 3], ['LAZY', 'lazy',
# 4], ['DOG', 'dog', 3]] (the list containing a list for every word of list
# words, where each list contains the word in uppercase and lowercase and the
# length of the word.)
# e) ['The', 'quick', 'brown', 'fox', 'jumps', 'over', 'the',
# 'lazy', 'dog'] (the list of words in list words containing 4 or more
# characters.)

# %%
words = ['The', 'quick', 'brown', 'fox', 'jumps', 'over','the', 'lazy', 'dog']  #defining the list
upper_list = []
lower_list = []
len_list = []
mix_list = []
four_char_list = []

for word in words:
    #converting list into uppercase
    upper_list.append(word.upper())   
    #converting list into lowercase
    lower_list.append(word.lower())   
    #printing lenght of the words in list
    len_list.append(len(word))        
    #printing the mix list
    mix_list.append([word.upper(), word.lower(), len(word)])    
    
    #printing word the list of words in list words containing 4 or more characters.
    if len(word) >= 4:                  
        four_char_list.append(word)

#printing list
print(upper_list)
print('\n')
print(lower_list)
print('\n')
print(len_list)
print('\n')
print(mix_list)
print('\n')
print(four_char_list)
['THE', 'QUICK', 'BROWN', 'FOX', 'JUMPS', 'OVER', 'THE', 'LAZY', 'DOG']


['the', 'quick', 'brown', 'fox', 'jumps', 'over', 'the', 'lazy', 'dog']


[3, 5, 5, 3, 5, 4, 3, 4, 3]

[['THE', 'the', 3], ['QUICK', 'quick', 5], ['BROWN', 'brown', 5], ['FOX', 'fox', 3], ['JUMPS', 'jumps', 5], ['OVER', 'over', 4], ['THE', 'the', 3], ['LAZY', 'lazy', 4], ['DOG', 'dog', 3]]


['quick', 'brown', 'jumps', 'over', 'lazy']
# Out:
# ['THE', 'QUICK', 'BROWN', 'FOX', 'JUMPS', 'OVER', 'THE', 'LAZY', 'DOG']
#
#
# ['the', 'quick', 'brown', 'fox', 'jumps', 'over', 'the', 'lazy', 'dog']
#
#
# [3, 5, 5, 3, 5, 4, 3, 4, 3]
#
#
# [['THE', 'the', 3], ['QUICK', 'quick', 5], ['BROWN', 'brown', 5], ['FOX', 'fox', 3], ['JUMPS', 'jumps', 5], ['OVER', 'over', 4], ['THE', 'the', 3], ['LAZY', 'lazy', 4], ['DOG', 'dog', 3]]
#
#
# ['quick', 'brown', 'jumps', 'over', 'lazy']
# ['quick', 'brown', 'jumps', 'over', 'lazy']
